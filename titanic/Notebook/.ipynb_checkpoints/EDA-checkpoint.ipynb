# %% [markdown]
# # Titanic dataset explore and feature engineer
#
# - 1.Data preprocess
#     - 1.1 load data
#     - 1.2 data explore

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %%
print "load data..."
train = pd.read_csv("../data/train.csv")
train.head(3)
# Out:
# load data...
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %% [markdown]
# ### Survived,Pclass,Sex,Embarked

# %%
fig = plt.figure()
fig.set(alpha=0.2)
fig.set_size_inches(16, 9)

plt.subplot2grid((2,2),(0,0))
train["Survived"].value_counts().plot(kind='bar')
plt.title('Titanic survived information,1 is survived,0 is unsurvived')
plt.xlabel('survived')
plt.ylabel('numbers')

plt.subplot2grid((2,2),(0,1))
train["Pclass"].value_counts().plot(kind='bar')
plt.title('Titanic pclass information')
plt.xlabel('Pclass')
plt.ylabel('numbers')

plt.subplot2grid((2,2),(1,0))
train["Sex"].value_counts().plot(kind='bar')
plt.title('Titanic Sex information')
plt.xlabel('Sex')

plt.subplot2grid((2,2),(1,1))
train["Embarked"].value_counts().plot(kind='bar')
plt.title('Titanic Embarked information')
plt.xlabel('Embarked')

plt.show()

# %% [markdown]
# Sex

# %%
survived = train['Sex'][train["Survived"] == 1].value_counts()
unsurvived = train['Sex'][train["Survived"] == 0].value_counts()

fig = plt.figure()
fig.set(alpha=0.2)
fig.set_size_inches(16, 9)

#female.plot(kind="bar", stacked=True)
df=pd.DataFrame({'Survived':survived, 'unSurvived':unsurvived})
df.plot(kind="bar")

plt.show()

# %% [markdown]
# Pclass

# %%
survived = train['Pclass'][train["Survived"] == 1].value_counts()
unsurvived = train['Pclass'][train["Survived"] == 0].value_counts()

fig = plt.figure()
fig.set(alpha=0.2)
fig.set_size_inches(16, 9)
#female.plot(kind="bar", stacked=True)
df=pd.DataFrame({'Survived':survived, 'unSurvived':unsurvived})
df.plot(kind="bar")

plt.show()

# %%
survived = train['Embarked'][train["Survived"] == 1].value_counts()
unsurvived = train['Embarked'][train["Survived"] == 0].value_counts()

fig = plt.figure()
fig.set(alpha=0.2)
fig.set_size_inches(16, 9)
#female.plot(kind="bar", stacked=True)
df=pd.DataFrame({'Survived':survived, 'unSurvived':unsurvived})
df.plot(kind="bar")

plt.show()
